# %% [markdown]
# <a href="https://colab.research.google.com/github/saurav81kumar/mini-project-of-ml/blob/main/placement_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/Placement.csv')

# %%
df.head()
# Out:
#    Student_ID  CGPA   IQ  Placement
# 0           1   6.8  123          1
# 1           2   5.9  106          0
# 2           3   5.3  121          0
# 3           4   7.4  132          1
# 4           5   5.8  142          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    CGPA   IQ  Placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0
# 3   7.4  132          1
# 4   5.8  142          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['CGPA'],df['IQ'],c=df['Placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     CGPA   IQ
# 0    6.8  123
# 1    5.9  106
# 2    5.3  121
# 3    7.4  132
# 4    5.8  142
# ..   ...  ...
# 95   4.3  200
# 96   4.4   42
# 97   6.7  182
# 98   6.3  103
# 99   6.2  113
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: Placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     CGPA   IQ
# 21   7.1  151
# 90   7.3   86
# 61   7.3  137
# 27   6.0  124
# 17   3.3  183
# ..   ...  ...
# 25   5.0   91
# 77   7.3   50
# 69   8.5  120
# 80   4.9  196
# 88   4.4  149
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 21    1
# 90    1
# 61    1
# 27    1
# 17    0
#      ..
# 25    0
# 77    1
# 69    1
# 80    0
# 88    0
# Name: Placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     CGPA   IQ
# 48   6.6  138
# 38   6.5  160
# 26   7.0  199
# 16   5.2  224
# 84   5.7  169
# 13   6.4  116
# 73   4.9   61
# 63   6.3  128
# 82   6.5   37
# 39   4.6  146

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.94481506,  0.773916  ],
#        [ 1.11556477, -0.96072331],
#        [ 1.11556477,  0.40030138],
#        [ 0.00569166,  0.05337352],
#        [-2.29942943,  1.62789227],
#        [ 0.00569166, -2.0548804 ],
#        [-1.0188066 ,  0.50704841],
#        [-0.84805689, -1.57451875],
#        [-0.93343175,  0.88066303],
#        [-1.10418146, -0.93403655],
#        [-0.50655747,  0.34692786],
#        [-1.0188066 , -0.26686758],
#        [ 0.85944021, -1.54783199],
#        [ 0.09106651, -1.52114523],
#        [ 0.09106651, -0.50704841],
#        [ 1.96931332,  1.22759089],
#        [-1.36030602, -2.13494068],
#        [-0.93343175,  0.3202411 ],
#        [-0.84805689, -0.10674703],
#        [-1.10418146, -1.86807309],
#        [-0.67730718, -0.85397627],
#        [ 0.85944021,  1.4143982 ],
#        [ 0.34719108,  0.50704841],
#        [-1.70180544, -1.25427765],
#        [ 0.26181622,  0.13343379],
#        [ 0.51794079, -0.05337352],
#        [-1.70180544, -0.58710869],
# ...

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.51794079,  0.42698814],
#        [ 0.43256593,  1.01409682],
#        [ 0.85944021,  2.0548804 ],
#        [-0.67730718,  2.72204937],
#        [-0.25043291,  1.25427765],
#        [ 0.34719108, -0.16012055],
#        [-0.93343175, -1.62789227],
#        [ 0.26181622,  0.16012055],
#        [ 0.43256593, -2.26837447],
#        [-1.18955631,  0.6404822 ]])

# %%
#creation of class
from sklearn.linear_model import LogisticRegression
#creation of object
model = LogisticRegression()
#model training
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#evaluate the model
y_pred = model.predict(x_test)

# %%
y_test
# Out:
# 48    1
# 38    1
# 26    1
# 16    0
# 84    0
# 13    1
# 73    0
# 63    1
# 82    1
# 39    0
# Name: Placement, dtype: int64

# %%
#calling of function
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=model, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(model,open('model.pkl','wb'))
